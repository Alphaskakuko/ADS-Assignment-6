# %%
import plotly.express as px

# Load Gapminder data into a Pandas DataFrame
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
import plotly.express as px

# Load Gapminder data into a Pandas DataFrame
df = px.data.gapminder()

# Filter data to include only Asian countries
df_asia = df[df['continent'] == 'Asia']

# Calculate the mean life expectancy of Asian countries
mean_life_exp = df_asia['lifeExp'].mean()

print('The mean life expectancy of all the Asian countries is:', round(mean_life_exp, 2))
# Out:
# The mean life expectancy of all the Asian countries is: 60.06

# %%
import plotly.express as px

# Load Gapminder data into a Pandas DataFrame
df = px.data.gapminder()

# Filter data to include only European and South American countries
df_europe_south_america = df[df['continent'].isin(['Europe', 'South America'])]

# Calculate the standard deviation of GDP per capita for each country
std_gdp = df_europe_south_america.groupby('country')['gdpPercap'].std()

print('Standard deviation of GDP per capita for each country in Europe and South America:')
print(std_gdp)
# Out:
# Standard deviation of GDP per capita for each country in Europe and South America:
# country
# Albania                    1192.351513
# Austria                    9655.281488
# Belgium                    8391.186269
# Bosnia and Herzegovina     1950.522347
# Bulgaria                   2351.963619
# Croatia                    3784.408663
# Czech Republic             4361.646747
# Denmark                    8305.077866
# Finland                    8360.170674
# France                     7903.234227
# Germany                    8076.261913
# Greece                     7289.928845
# Hungary                    3620.181984
# Iceland                    9373.245893
# Ireland                   11573.311022
# Italy                      8273.523174
# Montenegro                 2848.955200
# Netherlands                8918.866411
# Norway                    13421.947245
# Poland                     3198.351205
# Portugal                   6222.544894
# Romania                    2425.973541
# ...

# %%
import plotly.express as px

# Load Gapminder data into a Pandas DataFrame
df = px.data.gapminder()

# Filter data to include only African countries and the years between 1970 and 2000
df_africa = df[(df['continent'] == 'Africa') & (df['year'].isin([1970, 1980, 2000]))]

# Calculate the percentage change in population for each country over the three decades
df_africa_pivot = df_africa.pivot(index='country', columns='year', values='pop')
df_africa_pct_change = df_africa_pivot.pct_change(axis='columns').iloc[:, 1:]

print('Percentage change in population for each African country over the last 3 decades:')
print(df_africa_pct_change)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4960\1616048362.py in <module>
#       9 # Calculate the percentage change in population for each country over the three decades
#      10 df_africa_pivot = df_africa.pivot(index='country', columns='year', values='pop')
# ---> 11 df_africa_pct_change = df_africa_pivot.pct_change(axis='columns').iloc[:, 1:]
#      12
#      13 print('Percentage change in population for each African country over the last 3 decades:')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10369             data = _data
#   10370
# > 10371         shifted = data.shift(periods=periods, freq=freq, axis=axis, **kwargs)
#   10372         # Unsupported left operand type for / ("NDFrameT")
# ...
